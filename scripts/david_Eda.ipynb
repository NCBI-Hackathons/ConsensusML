# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', 50)

# %%
wt_disc_df = pd.read_excel('../Clinical_Data/TARGET_WT_ClinicalData_Discovery_20160714_public.xlsx')

# %%
wt_disc_df.head()
# Out:
#          TARGET USI  Gender   Race               Ethnicity  \
# 0  TARGET-50-CAAAAA  Female  White            Not reported
# 1  TARGET-50-CAAAAB  Female  White            Not reported
# 2  TARGET-50-CAAAAC  Female  White  Not Hispanic or Latino
# 3  TARGET-50-CAAAAH  Female  White            Not reported
# 4  TARGET-50-CAAAAJ  Female  White  Not Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      2068     Relapse                               475
# 1                      1757     Relapse                               635
# 2                      2244     Relapse                              1184
# 3                      1710     Relapse                               165
# 4                       401     Relapse                               169
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 0         DEAD                            475               1993
# ...

# %%
wt_val_df = pd.read_excel('../Clinical_Data/TARGET_WT_ClinicalData_Validation_20160714_public.xlsx')

# %%
wt_val_df.head()
# Out:
#          TARGET USI  Gender          Race               Ethnicity  \
# 0  TARGET-50-PACFNR  Female         White  Not Hispanic or Latino
# 1  TARGET-50-PADCRV    Male         White  Not Hispanic or Latino
# 2  TARGET-50-PADDLL  Female         White  Not Hispanic or Latino
# 3  TARGET-50-PADVNN    Male         White  Not Hispanic or Latino
# 4  TARGET-50-PADWHM  Female  Not reported      Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      1215        None                              3943
# 1                      2523     Relapse                               271
# 2                       193        None                              1552
# 3                      2268     Relapse                               521
# 4                       724     Relapse                               167
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# ...

# %%
wt_val_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 19 columns):
# TARGET USI                                   526 non-null object
# Gender                                       526 non-null object
# Race                                         526 non-null object
# Ethnicity                                    526 non-null object
# Age at Diagnosis in Days                     526 non-null int64
# First Event                                  526 non-null object
# Event Free Survival Time in Days             526 non-null int64
# Vital Status                                 526 non-null object
# Overall Survival Time in Days                526 non-null int64
# Year of Diagnosis                            526 non-null int64
# Year of Last Follow Up                       526 non-null int64
# Protocol                                     526 non-null object
# Stage                                        521 non-null object
# ...

# %% [markdown]
# # Discovery EDA

# %%
wt_disc_df.head()
# Out:
#          TARGET USI  Gender   Race               Ethnicity  \
# 0  TARGET-50-CAAAAA  Female  White            Not reported
# 1  TARGET-50-CAAAAB  Female  White            Not reported
# 2  TARGET-50-CAAAAC  Female  White  Not Hispanic or Latino
# 3  TARGET-50-CAAAAH  Female  White            Not reported
# 4  TARGET-50-CAAAAJ  Female  White  Not Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      2068     Relapse                               475
# 1                      1757     Relapse                               635
# 2                      2244     Relapse                              1184
# 3                      1710     Relapse                               165
# 4                       401     Relapse                               169
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 0         DEAD                            475               1993
# ...

# %%
manifest_df = pd.read_csv('../GCD_TARGET_Data_Manifest_AML_NBL_WT_RT.csv')

# %%
wt_mani = manifest_df[manifest_df['project.project_id'] == 'TARGET-WT']

# %%
wt_mani.head()
# Out:
#                          data_type                  updated_datetime  \
# 8   Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 9   Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 10  Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 11  Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 12  Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
#
#                                             file_name  \
# 8   8b14a563-bd4f-4f76-95f2-608c4ba95120.htseq.cou...
# 9   5a9177ab-1d15-4f71-8abe-8e8acdc2c08e.htseq.cou...
# 10  5cc3c136-8c26-4740-bc19-ee93d0ff878d.htseq.cou...
# 11  8328c0ca-dcb9-4ebd-9be7-4d33e371b18e.htseq.cou...
# 12  bde9c657-1c07-4235-a382-6e335a08e2f2.htseq.cou...
#
#                                   submitter_id  \
# 8   8b14a563-bd4f-4f76-95f2-608c4ba95120_count
# 9   5a9177ab-1d15-4f71-8abe-8e8acdc2c08e_count
# 10  5cc3c136-8c26-4740-bc19-ee93d0ff878d_count
# ...

# %%
wt_mani['entity_submitter_id'][8][0:16]
# Out:
# 'TARGET-50-PALKRS'

# %%
wt_mani['TARGET USI'] = wt_mani.loc[:, 'entity_submitter_id'].apply(lambda x: x[:16])
# Out:
# /Users/david/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
wt_mani.head()
# Out:
#                          data_type                  updated_datetime  \
# 8   Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 9   Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 10  Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 11  Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
# 12  Gene Expression Quantification  2018-11-30T04:41:54.381022+00:00
#
#                                             file_name  \
# 8   8b14a563-bd4f-4f76-95f2-608c4ba95120.htseq.cou...
# 9   5a9177ab-1d15-4f71-8abe-8e8acdc2c08e.htseq.cou...
# 10  5cc3c136-8c26-4740-bc19-ee93d0ff878d.htseq.cou...
# 11  8328c0ca-dcb9-4ebd-9be7-4d33e371b18e.htseq.cou...
# 12  bde9c657-1c07-4235-a382-6e335a08e2f2.htseq.cou...
#
#                                   submitter_id  \
# 8   8b14a563-bd4f-4f76-95f2-608c4ba95120_count
# 9   5a9177ab-1d15-4f71-8abe-8e8acdc2c08e_count
# 10  5cc3c136-8c26-4740-bc19-ee93d0ff878d_count
# ...

# %%
wt_disc_df.head()
# Out:
#          TARGET USI  Gender   Race               Ethnicity  \
# 0  TARGET-50-CAAAAA  Female  White            Not reported
# 1  TARGET-50-CAAAAB  Female  White            Not reported
# 2  TARGET-50-CAAAAC  Female  White  Not Hispanic or Latino
# 3  TARGET-50-CAAAAH  Female  White            Not reported
# 4  TARGET-50-CAAAAJ  Female  White  Not Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      2068     Relapse                               475
# 1                      1757     Relapse                               635
# 2                      2244     Relapse                              1184
# 3                      1710     Relapse                               165
# 4                       401     Relapse                               169
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 0         DEAD                            475               1993
# ...

# %%
WT_df = wt_disc_df.merge(wt_mani, on='TARGET USI')
