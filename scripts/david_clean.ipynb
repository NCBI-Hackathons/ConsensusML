# %%
import numpy as np
import pandas as pd

# %%
from clean import manifest_clinical_merge

# %%
pd.set_option('display.max_columns', 50)

# %%
manifest_df = pd.read_csv('../GCD_TARGET_Data_Manifest_AML_NBL_WT_RT.csv')

# %%
manifest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 20 columns):
# data_type                474 non-null object
# updated_datetime         474 non-null object
# file_name                474 non-null object
# submitter_id             474 non-null object
# file_id                  474 non-null object
# file_size                474 non-null int64
# id                       474 non-null object
# created_datetime         474 non-null object
# md5sum                   474 non-null object
# data_format              474 non-null object
# access                   474 non-null object
# state                    474 non-null object
# data_category            474 non-null object
# type                     474 non-null object
# experimental_strategy    474 non-null object
# project.project_id       474 non-null object
# entity_id                474 non-null object
# case_id                  474 non-null object
# entity_submitter_id      474 non-null object
# entity_type              474 non-null object
# dtypes: int64(1), object(19)
# memory usage: 74.1+ KB

# %% [markdown]
# # pull discovery data into pandas

# %%
wt_disc_df = pd.read_excel('../Clinical_Data/TARGET_WT_ClinicalData_Discovery_20160714_public.xlsx')
aml_disc_df = pd.read_excel('../Clinical_Data/TARGET_AML_ClinicalData_20160714.xlsx')
nbl_disc_df = pd.read_excel('../Clinical_Data/TARGET_NBL_ClinicalData_20151124.xlsx')

# %%
WT_df = manifest_clinical_merge(manifest_df, wt_disc_df, 'TARGET-WT')
AML_df = manifest_clinical_merge(manifest_df, aml_disc_df, 'TARGET-AML')
NBL_df = manifest_clinical_merge(manifest_df, nbl_disc_df, 'TARGET-NBL')
# Out:
# /Users/david/statsbomb/RNAseq_Cancer_Biomarkers/scripts/clean.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   target_df['TARGET USI'] = target_df.loc[:, 'entity_submitter_id'].apply(lambda x: x[:16])

# %%
WT_df.head()
# Out:
#          TARGET USI  Gender                       Race  \
# 0  TARGET-50-CAAAAC  Female                      White
# 1  TARGET-50-CAAAAH  Female                      White
# 2  TARGET-50-CAAAAJ  Female                      White
# 3  TARGET-50-CAAAAL  Female  Black or African American
# 4  TARGET-50-CAAAAM  Female                      White
#
#                 Ethnicity  Age at Diagnosis in Days First Event  \
# 0  Not Hispanic or Latino                      2244     Relapse
# 1            Not reported                      1710     Relapse
# 2  Not Hispanic or Latino                       401     Relapse
# 3  Not Hispanic or Latino                      1599     Relapse
# 4  Not Hispanic or Latino                      2750        None
#
#    Event Free Survival Time in Days Vital Status  \
# 0                              1184         DEAD
# 1                               165         DEAD
# 2                               169        ALIVE
# 3                               221        ALIVE
# 4                              3260        ALIVE
#
#    Overall Survival Time in Days  Year of Diagnosis  Year of Last Follow Up  \
# 0                           2615               1996                    2003
# 1                            311               1993                    1994
# 2                           3385               1996                    2005
# 3                           3289               1996                    2011
# 4                           3260               1996                    2009
#
#   Protocol Stage ICD-O-3-M ICD-O-3-T  \
# 0   NWTS-5   III    8960/3      C649
# 1   NWTS-4   III    8960/3      C649
# 2   NWTS-5    IV    8960/3      C649
# 3   NWTS-5   III    8960/3      C649
# 4   NWTS-5   III    8960/3      C649
#
#   Histology Classification of Primary Tumor Reason for Death Comment   \
# 0                                      FHWT            TUMOR   PADWYI
# 1                                      DAWT            TUMOR   PAHZZL
# 2                                      FHWT             None   PADWMG
# 3                                      FHWT             None   PADXUJ
# 4                                      DAWT             None   PADYGU
#
#   Discovery or Validation                       data_type  \
# 0               Discovery  Gene Expression Quantification
# 1               Discovery  Gene Expression Quantification
# 2               Discovery  Gene Expression Quantification
# 3               Discovery  Gene Expression Quantification
# 4               Discovery  Gene Expression Quantification
#
#                    updated_datetime  \
# 0  2018-11-30T04:41:54.381022+00:00
# 1  2018-11-30T04:41:54.381022+00:00
# 2  2018-11-30T04:41:54.381022+00:00
# 3  2018-11-30T04:41:54.381022+00:00
# 4  2018-11-30T04:41:54.381022+00:00
#
#                                            file_name  \
# 0  a4e8501a-254e-424d-9dd1-c499076e610a.htseq.cou...
# 1  33e78a8d-8d8d-4887-a046-162179f8e4b7.htseq.cou...
# 2  63cfe1ee-d1eb-43ae-94e6-a720afdab7bb.htseq.cou...
# 3  d57523f8-07a4-40d0-b0d9-74ebc101344c.htseq.cou...
# 4  2f9947cd-3b85-42f1-8c02-80511fc3f745.htseq.cou...
#
#                                  submitter_id  \
# 0  a4e8501a-254e-424d-9dd1-c499076e610a_count
# 1  33e78a8d-8d8d-4887-a046-162179f8e4b7_count
# 2  63cfe1ee-d1eb-43ae-94e6-a720afdab7bb_count
# 3  d57523f8-07a4-40d0-b0d9-74ebc101344c_count
# 4  2f9947cd-3b85-42f1-8c02-80511fc3f745_count
#
#                                 file_id  file_size  \
# 0  6ffacd87-f3ea-4306-9f9b-3ff5381c38cb     257998
# 1  47a55228-2521-4598-a0e0-f6e36649cf1b     259739
# 2  99898737-a2d5-41b4-8e81-be7f5d7cc473     259080
# 3  684c36f4-1782-47dc-b7f0-fa56a086b14f     257653
# 4  3f34422d-fc73-48fa-ba76-1469de795274     257761
#
#                                      id                  created_datetime  \
# 0  6ffacd87-f3ea-4306-9f9b-3ff5381c38cb  2016-06-01T23:27:42.148644-05:00
# 1  47a55228-2521-4598-a0e0-f6e36649cf1b  2016-06-01T23:30:06.618155-05:00
# 2  99898737-a2d5-41b4-8e81-be7f5d7cc473  2016-06-01T23:27:33.323285-05:00
# 3  684c36f4-1782-47dc-b7f0-fa56a086b14f  2016-06-01T23:30:56.498098-05:00
# 4  3f34422d-fc73-48fa-ba76-1469de795274  2016-06-01T23:30:04.719166-05:00
#
#                              md5sum data_format access     state  \
# 0  9058c483ea002b22e6fbd5422d296c5a         TXT   open  released
# 1  f08dab16cee034b90b85f0ea9b93f654         TXT   open  released
# 2  3fce47bb8e41747165f77f48d9db207d         TXT   open  released
# 3  2f9690e861950a3a7e394c1f810ae176         TXT   open  released
# 4  4d07f755473704ca14acfffd58b71085         TXT   open  released
#
#              data_category             type experimental_strategy  \
# 0  Transcriptome Profiling  gene_expression               RNA-Seq
# 1  Transcriptome Profiling  gene_expression               RNA-Seq
# 2  Transcriptome Profiling  gene_expression               RNA-Seq
# 3  Transcriptome Profiling  gene_expression               RNA-Seq
# 4  Transcriptome Profiling  gene_expression               RNA-Seq
#
#   project.project_id                             entity_id  \
# 0          TARGET-WT  37261c1b-6171-5973-9588-dc392c843ac5
# 1          TARGET-WT  be1a1d02-4015-5f99-8619-6571ab91eb79
# 2          TARGET-WT  57e1badd-d577-5184-b02d-cd40bb2b0c77
# 3          TARGET-WT  671a91de-47f2-5cb6-8b61-99aa1c2d3429
# 4          TARGET-WT  5a77076c-4ed9-5522-a3a5-39aade2672a1
#
#                                 case_id       entity_submitter_id entity_type
# 0  b6c4b6f9-1941-55b6-a66c-1758167faa2c  TARGET-50-CAAAAC-01A-01R     aliquot
# 1  dee14127-42e8-55db-8aed-58a7416226c8  TARGET-50-CAAAAH-01A-01R     aliquot
# 2  b2494bc4-4569-56b6-9baa-7a5e4cf36711  TARGET-50-CAAAAJ-01A-01R     aliquot
# 3  f8ea90e4-af7f-5f6f-a22b-804b07fefa6f  TARGET-50-CAAAAL-01A-01R     aliquot
# 4  de741bc5-b711-504d-b5ac-fbcc34570c58  TARGET-50-CAAAAM-01A-01R     aliquot

# %%
AML_df.head()
# Out:
#          TARGET USI  Gender     Race               Ethnicity  \
# 0  TARGET-20-PABLDZ  Female    White  Not Hispanic or Latino
# 1  TARGET-20-PADYIR    Male    White  Not Hispanic or Latino
# 2  TARGET-20-PADYIR    Male    White  Not Hispanic or Latino
# 3  TARGET-20-PADZCG  Female  Unknown  Not Hispanic or Latino
# 4  TARGET-20-PADZCG  Female  Unknown  Not Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      2455     Relapse                               714
# 1                      1159     Relapse                               373
# 2                      1159     Relapse                               373
# 3                      5325     Relapse                               314
# 4                      5325     Relapse                               314
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 0        Alive                            721               1997
# 1         Dead                            585               1996
# 2         Dead                            585               1996
# 3         Dead                            536               1996
# 4         Dead                            536               1996
#
#    Year of Last Follow Up  Protocol  WBC at Diagnosis  \
# 0                    1999  CCG-2961               6.0
# 1                    1998  CCG-2961              13.1
# 2                    1998  CCG-2961              13.1
# 3                    1998  CCG-2961              29.3
# 4                    1998  CCG-2961              29.3
#
#   Bone marrow leukemic blast percentage (%) Peripheral blasts (%) CNS disease  \
# 0                                        93                     0          No
# 1                                        29                    11          No
# 2                                        29                    11          No
# 3                                        58                     5          No
# 4                                        58                     5          No
#
#   Chloroma FAB Category   t(6;9)  t(8;21) t(3;5)(q25;q34) t(6;11)(q27;q23)  \
# 0       No           M4  Unknown  Unknown         Unknown          Unknown
# 1       No           M2  Unknown  Unknown         Unknown          Unknown
# 2       No           M2  Unknown  Unknown         Unknown          Unknown
# 3       No           M4       No       No              No               No
# 4       No           M4       No       No              No               No
#
#   t(9;11)(p22;q23) t(10;11)(p11.2;q23) t(11:19)(q23:p13.1)     ...      \
# 0          Unknown             Unknown             Unknown     ...
# 1          Unknown             Unknown             Unknown     ...
# 2          Unknown             Unknown             Unknown     ...
# 3               No                  No                  No     ...
# 4               No                  No                  No     ...
#
#   Chloroma Site of Relapse/Induction Failure  \
# 0                                         No
# 1                                         No
# 2                                         No
# 3                                         No
# 4                                         No
#
#   Cytogenetic Site of Relapse/Induction Failure  \
# 0                                            No
# 1                                            No
# 2                                            No
# 3                                            No
# 4                                            No
#
#   Other Site of Relapse/Induction Failure               Comment  \
# 0                                      No  Discovery,Validation
# 1                                      No  Discovery,Validation
# 2                                      No  Discovery,Validation
# 3                                      No  Discovery,Validation
# 4                                      No  Discovery,Validation
#
#   Refractory Timepoint sent for Induction Failure Project  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                         data_type                  updated_datetime  \
# 0  Gene Expression Quantification  2018-11-30T04:41:54.825530+00:00
# 1  Gene Expression Quantification  2018-11-30T04:41:54.825530+00:00
# 2  Gene Expression Quantification  2018-11-30T04:41:54.825530+00:00
# 3  Gene Expression Quantification  2018-11-30T04:41:54.825530+00:00
# 4  Gene Expression Quantification  2018-11-30T04:41:54.825530+00:00
#
#                                            file_name  \
# 0  32884be7-c25f-42be-a0ae-c4b124094b52.htseq.cou...
# 1  76e73494-af7e-4fb1-92d4-11b59ae2d9f7.htseq.cou...
# 2  6b57be91-5813-4522-9fd2-dae0e0c616e3.htseq.cou...
# 3  11b78e34-e8ad-4ee3-a1d1-1a5ba1974698.htseq.cou...
# 4  cc48604f-e6dd-4213-ae0b-56334762d9e7.htseq.cou...
#
#                                  submitter_id  \
# 0  32884be7-c25f-42be-a0ae-c4b124094b52_count
# 1  76e73494-af7e-4fb1-92d4-11b59ae2d9f7_count
# 2  6b57be91-5813-4522-9fd2-dae0e0c616e3_count
# 3  11b78e34-e8ad-4ee3-a1d1-1a5ba1974698_count
# 4  cc48604f-e6dd-4213-ae0b-56334762d9e7_count
#
#                                 file_id file_size  \
# 0  9bd47482-66a2-4866-afec-e2dab32f6059    248754
# 1  21299487-9511-47e8-80ae-8839492140e0    255929
# 2  e62a6d69-90e8-43ee-9245-e61157575f47    261470
# 3  7074db0d-84a5-4388-957e-c68a5cef4f56    263416
# 4  9f66d426-54ff-4f7b-9564-885a0d9fd109    249625
#
#                                      id                  created_datetime  \
# 0  9bd47482-66a2-4866-afec-e2dab32f6059  2016-06-01T23:23:15.490207-05:00
# 1  21299487-9511-47e8-80ae-8839492140e0  2016-06-01T23:26:37.020551-05:00
# 2  e62a6d69-90e8-43ee-9245-e61157575f47  2016-06-01T23:26:37.834321-05:00
# 3  7074db0d-84a5-4388-957e-c68a5cef4f56  2016-06-01T23:29:15.887495-05:00
# 4  9f66d426-54ff-4f7b-9564-885a0d9fd109  2016-06-01T23:29:15.273294-05:00
#
#                              md5sum data_format access     state  \
# 0  eb61046f3223ec3d0b6c5de9e165a5a8         TXT   open  released
# 1  57913f29e2d5721d62265ee257ba6797         TXT   open  released
# 2  b3f438ab15269218395821b4ca704c11         TXT   open  released
# 3  c9e359c1e71c15c5ef9c0c23782d9a09         TXT   open  released
# 4  09e30272160bbfd22307a3eed45c03d9         TXT   open  released
#
#              data_category             type experimental_strategy  \
# 0  Transcriptome Profiling  gene_expression               RNA-Seq
# 1  Transcriptome Profiling  gene_expression               RNA-Seq
# 2  Transcriptome Profiling  gene_expression               RNA-Seq
# 3  Transcriptome Profiling  gene_expression               RNA-Seq
# 4  Transcriptome Profiling  gene_expression               RNA-Seq
#
#   project.project_id                             entity_id  \
# 0         TARGET-AML  c78f2949-4050-5f14-a401-beddf3ff9f61
# 1         TARGET-AML  6080729a-0c28-5708-ab73-1cadd5899a07
# 2         TARGET-AML  fa12e7d2-34bf-50f5-83f0-f52993d971cb
# 3         TARGET-AML  1507ac24-8ba2-5e57-a05a-86b5157c8377
# 4         TARGET-AML  5f49d1ae-e832-59de-89e1-93b6327232f0
#
#                                 case_id       entity_submitter_id entity_type
# 0  1e5c8323-383d-51a0-9199-1b9504b29c7e  TARGET-20-PABLDZ-04A-01R     aliquot
# 1  965d5966-baf3-5496-afb8-df8e164365a3  TARGET-20-PADYIR-04A-01R     aliquot
# 2  965d5966-baf3-5496-afb8-df8e164365a3  TARGET-20-PADYIR-09A-01R     aliquot
# 3  c3670ebd-1d43-5491-ac10-a158e12c560b  TARGET-20-PADZCG-09A-02R     aliquot
# 4  c3670ebd-1d43-5491-ac10-a158e12c560b  TARGET-20-PADZCG-04A-01R     aliquot
#
# [5 rows x 83 columns]

# %%
NBL_df.head()
# Out:
#          TARGET USI  Gender   Race               Ethnicity  \
# 0  TARGET-30-PAIFXV  Female  White                 Unknown
# 1  TARGET-30-PAIPGU  Female  White                 Unknown
# 2  TARGET-30-PAISNS    Male  White                 Unknown
# 3  TARGET-30-PAITCI    Male  White                 Unknown
# 4  TARGET-30-PAIVHE    Male  White  Not Hispanic or Latino
#
#    Age at Diagnosis in Days First Event  Event Free Survival Time in Days  \
# 0                      2004       Event                             630.0
# 1                       898       Death                             436.0
# 2                      1070       Event                             410.0
# 3                       728       Event                             232.0
# 4                      1123       Event                             672.0
#
#   Vital Status  Overall Survival Time in Days  Year of Diagnosis  \
# 0         Dead                         1114.0               1995
# 1         Dead                          436.0               1998
# 2         Dead                          421.0               1998
# 3         Dead                          324.0               1998
# 4         Dead                         1605.0               1999
#
#    Year of Last Follow Up                       Protocol INSS Stage  \
# 0                  1998.0  9047, 9340, 9341, 9342, P9462    Stage 4
# 1                  1999.0                           9047    Stage 4
# 2                  1999.0                    9047, P9462    Stage 4
# 3                  1999.0                     9047, 9082    Stage 4
# 4                  2003.0          9047, P9462, ANBL0321    Stage 4
#
#      MYCN status               Ploidy  Ploidy Value    Histology  \
# 0  Not Amplified  Hyperdiploid (DI>1)          1.06  Unfavorable
# 1  Not Amplified  Hyperdiploid (DI>1)          1.04      Unknown
# 2  Not Amplified       Diploid (DI=1)          1.00      Unknown
# 3  Not Amplified  Hyperdiploid (DI>1)          1.92    Favorable
# 4  Not Amplified  Hyperdiploid (DI>1)          1.06  Unfavorable
#
#                                        Grade      MKI Diagnostic Category  \
# 0                                    Unknown  Unknown             Unknown
# 1                                    Unknown  Unknown             Unknown
# 2                                    Unknown  Unknown             Unknown
# 3                            Differentiating      Low       Neuroblastoma
# 4  Undifferentiated or Poorly Differentiated      Low       Neuroblastoma
#
#       ICDO                                   ICDO Description COG Risk Group  \
# 0  Unknown              ABDOMEN/PERITONEUM OR RETROPERITONEUM      High Risk
# 1  Unknown                                      ADRENAL GLAND      High Risk
# 2  Unknown                                      ADRENAL GLAND      High Risk
# 3  Unknown                                      ADRENAL GLAND      High Risk
# 4    C74.9  Adrenal gland, NOS  Suprarenal gland  Adrenal,...      High Risk
#
#   Percent Tumor Percent Necrosis     ...     Site Relapse  \
# 0           NaN              NaN     ...              NaN
# 1            90               10     ...              NaN
# 2         80-90                5     ...              NaN
# 3            90               10     ...              NaN
# 4            90               10     ...              NaN
#
#   Relapse Percent Tumor Relapse Percent Necrosis  \
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# 3                   NaN                      NaN
# 4                   NaN                      NaN
#
#   Relapse Percent Tumor v/s Stroma  Comment                       data_type  \
# 0                              NaN      NaN  Gene Expression Quantification
# 1                              NaN      NaN  Gene Expression Quantification
# 2                              NaN      NaN  Gene Expression Quantification
# 3                              NaN      NaN  Gene Expression Quantification
# 4                              NaN      NaN  Gene Expression Quantification
#
#                    updated_datetime  \
# 0  2018-11-30T04:41:54.945003+00:00
# 1  2018-11-30T04:41:54.945003+00:00
# 2  2018-11-30T04:41:54.945003+00:00
# 3  2018-11-30T04:41:54.945003+00:00
# 4  2018-11-30T04:41:54.945003+00:00
#
#                                            file_name  \
# 0  d8d30bd7-608d-4cbd-ba31-3f1fa6fefacf.htseq.counts
# 1  4f13947f-1cf8-44d6-bdb6-13f9668dbcfd.htseq.counts
# 2  4aae239e-9b2e-4a89-af99-ae4f3cbe1fff.htseq.counts
# 3  1eb90879-2cb0-4cc2-ae58-eefacd1715d0.htseq.counts
# 4  f7541bf7-73bc-4163-af01-3fea29027a16.htseq.counts
#
#                            submitter_id                               file_id  \
# 0  test_version109_GeneExpressionCounts  cfa24f91-5cea-4a45-8a00-afbebaea462b
# 1   test_version46_GeneExpressionCounts  18e284a1-0fb0-4e90-bdf5-a6d2464e26af
# 2   test_version10_GeneExpressionCounts  e0ae7fad-cf09-4fbc-be8c-6f66ded89d31
# 3   test_version75_GeneExpressionCounts  1888e5bd-fd6b-48cb-a59e-46a6e4518d11
# 4   test_version44_GeneExpressionCounts  a0f85380-dc8e-4424-985f-36c5d6fb861c
#
#   file_size                                    id  \
# 0   1272287  cfa24f91-5cea-4a45-8a00-afbebaea462b
# 1   1266903  18e284a1-0fb0-4e90-bdf5-a6d2464e26af
# 2   1263281  e0ae7fad-cf09-4fbc-be8c-6f66ded89d31
# 3   1269445  1888e5bd-fd6b-48cb-a59e-46a6e4518d11
# 4   1271260  a0f85380-dc8e-4424-985f-36c5d6fb861c
#
#                    created_datetime                            md5sum  \
# 0  2017-10-06T08:29:48.873012-05:00  d86ccd5f9ed8f123c25a600b66ed7f43
# 1  2017-10-06T08:25:15.152144-05:00  5e88e02d2221f6dc65abb314a115fc53
# 2  2017-10-06T08:22:37.905981-05:00  d8ca804502931daa3eed89a0e702dc9f
# 3  2017-10-06T08:27:34.954478-05:00  bcfeea5d06baf1f4bb126a8a62cb2ef1
# 4  2017-10-06T08:24:52.252607-05:00  6e63c261ad1362cbb12f2acd2f501aa8
#
#   data_format access     state            data_category             type  \
# 0         TXT   open  released  Transcriptome Profiling  gene_expression
# 1         TXT   open  released  Transcriptome Profiling  gene_expression
# 2         TXT   open  released  Transcriptome Profiling  gene_expression
# 3         TXT   open  released  Transcriptome Profiling  gene_expression
# 4         TXT   open  released  Transcriptome Profiling  gene_expression
#
#   experimental_strategy project.project_id  \
# 0               RNA-Seq         TARGET-NBL
# 1               RNA-Seq         TARGET-NBL
# 2               RNA-Seq         TARGET-NBL
# 3               RNA-Seq         TARGET-NBL
# 4               RNA-Seq         TARGET-NBL
#
#                               entity_id                               case_id  \
# 0  f040bca5-d68f-533e-befc-be9399eaa73a  4a47a989-5650-5366-9c83-4fa7e1deaa83
# 1  f02dbb19-bf67-53fd-a201-54d02322264c  68779778-b56c-5cb0-9eef-03945dddc402
# 2  02e457e4-408a-50ca-90f0-e7cab928aa8d  2f3d43b1-2c71-51ad-a49e-a24c2b933f9e
# 3  bb71de8a-eb6c-50f9-8d9d-cf096bdd7df6  050f88fb-d776-52b1-8c33-d646d7c1e8ab
# 4  26d3cbe3-e960-5ea5-9002-fe3d15a66712  6d07ecd4-e96c-51ff-8a00-952e3c785871
#
#         entity_submitter_id entity_type
# 0  TARGET-30-PAIFXV-01A-01R     aliquot
# 1  TARGET-30-PAIPGU-01A-01R     aliquot
# 2  TARGET-30-PAISNS-01A-01R     aliquot
# 3  TARGET-30-PAITCI-01A-01R     aliquot
# 4  TARGET-30-PAIVHE-01A-01R     aliquot
#
# [5 rows x 52 columns]

# %%
manifest_df['project.project_id'].value_counts()
# Out:
# TARGET-AML    187
# TARGET-NBL    150
# TARGET-WT     132
# TARGET-RT       5
# Name: project.project_id, dtype: int64

# %%
AML_df.to_csv('../Clinical_Data/AML_dataframe.csv')

# %%
NBL_df.to_csv('../Clinical_Data/NBL_dataframe.csv')
WT_df.to_csv('../Clinical_Data/WT_dataframe.csv')
