# %%
import numpy as np
import pandas as pd

# %%
from clean import manifest_clinical_merge

# %%
pd.set_option('display.max_columns', 50)

# %%
manifest_df = pd.read_csv('../GCD_TARGET_Data_Manifest_AML_NBL_WT_RT.csv')

# %% [markdown]
# # pull discovery data into pandas

# %%
wt_disc_df = pd.read_excel('../Clinical_Data/TARGET_WT_ClinicalData_Discovery_20160714_public.xlsx')
rt_disc_df = pd.read_excel('../Clinical_Data/TARGET_RT_ClinicalData_Discovery_20150710_public.xlsx')
os_disc_df = pd.read_excel('../Clinical_Data/TARGET_OS_ClinicalData_Discovery_20150729.xlsx')

# %%
WT_df = manifest_clinical_merge(manifest_df, wt_disc_df, 'TARGET-WT')
# Out:
# /Users/david/statsbomb/RNAseq_Cancer_Biomarkers/scripts/clean.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   target_df['TARGET USI'] = target_df.loc[:, 'entity_submitter_id'].apply(lambda x: x[:16])

# %%
WT_df.head()
# Out:
#          TARGET USI  Gender                       Race  \
# 0  TARGET-50-CAAAAC  Female                      White
# 1  TARGET-50-CAAAAH  Female                      White
# 2  TARGET-50-CAAAAJ  Female                      White
# 3  TARGET-50-CAAAAL  Female  Black or African American
# 4  TARGET-50-CAAAAM  Female                      White
#
#                 Ethnicity  Age at Diagnosis in Days First Event  \
# 0  Not Hispanic or Latino                      2244     Relapse
# 1            Not reported                      1710     Relapse
# 2  Not Hispanic or Latino                       401     Relapse
# 3  Not Hispanic or Latino                      1599     Relapse
# 4  Not Hispanic or Latino                      2750        None
#
#    Event Free Survival Time in Days Vital Status  \
# 0                              1184         DEAD
# 1                               165         DEAD
# 2                               169        ALIVE
# ...

# %%
RT_df = manifest_clinical_merge(manifest_df, rt_disc_df, 'TARGET-RT')
OS_df = manifest_clinical_merge(manifest_df, os_disc_df, 'TARGET-OS')
# Out:
# /Users/david/statsbomb/RNAseq_Cancer_Biomarkers/scripts/clean.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   target_df['TARGET USI'] = target_df.loc[:, 'entity_submitter_id'].apply(lambda x: x[:16])

# %%
RT_df.head()
# Out:
#          TARGET USI   Gender   Race               Ethnicity  \
# 0  TARGET-52-PARPFY     Male  White  Not Hispanic or Latino
# 1  TARGET-52-PARRCL   Female  White      Hispanic or Latino
# 2  TARGET-52-PARZBI   Female  White  Not Hispanic or Latino
# 3  TARGET-52-PASDLA   Female  White      Hispanic or Latino
# 4  TARGET-52-PAUDPV   Female  White  Not Hispanic or Latino
#
#    Age at Diagnosis in Days              First Event  \
# 0                       361  Death Without Remission
# 1                       214                     None
# 2                       526                  Relapse
# 3                       332                     None
# 4                        54  Death Without Remission
#
#    Event Free Survival Time in Days Vital status  \
# 0                             102.0         Dead
# 1                            2577.0        Alive
# 2                             233.0         Dead
# 3                            2399.0        Alive
# ...

# %%
OS_df.head()
# Out:
# Empty DataFrame
# Columns: [TARGET USI, Gender, Race, Ethnicity, Age at Diagnosis in Days, First Event, Time to First Event in Days, Vital Status , Overall Survival Time in Days, Year of Diagnosis, Year of Last Follow Up, Protocol, Disease at diagnosis, Metastasis site, Primary tumor site, Specific tumor site, Specific tumor side, Specific tumor region, Definitive Surgery, Primary site progression, Site of initial relapse, Time to first relapse in days, Time to first enrollment on relapse protocol in days, Time to first SMN in days, Time to death in days, Histologic response, Percent necrosis, Relapse Type, Therapy, Comment, data_type, updated_datetime, file_name, submitter_id, file_id, file_size, id, created_datetime, md5sum, data_format, access, state, data_category, type, experimental_strategy, project.project_id, entity_id, case_id, entity_submitter_id, entity_type]
# Index: []

# %%
os_disc_df['TARGET USI']
# Out:
# 0     TARGET-40-PALWWX
# 1     TARGET-40-PAMEKS
# 2     TARGET-40-PAMLKS
# 3     TARGET-40-PAMRHD
# 4     TARGET-40-PAMYYJ
# 5     TARGET-40-PANMIG
# 6     TARGET-40-PANPUM
# 7     TARGET-40-PANZHX
# 8     TARGET-40-PAPIJR
# 9     TARGET-40-PAPKWD
# 10    TARGET-40-PAPNVD
# 11    TARGET-40-PAPWWC
# 12    TARGET-40-PAPXGT
# 13    TARGET-40-PARBGW
# 14    TARGET-40-PARDAX
# 15    TARGET-40-PARFTG
# 16    TARGET-40-PARGTM
# 17    TARGET-40-PARJXU
# 18    TARGET-40-PARKAF
# 19    TARGET-40-PASEBY
# 20    TARGET-40-PASEFS
# 21    TARGET-40-PASFCV
# 22    TARGET-40-PASKZZ
# 23    TARGET-40-PASSLM
# 24    TARGET-40-PASUUH
# 25    TARGET-40-PASYUK
# 26    TARGET-40-PATAWV
# 27    TARGET-40-PATJVI
# 28    TARGET-40-PATKSS
# 29    TARGET-40-PATMIF
#             ...
# 59    TARGET-40-0A4I4E
# 60    TARGET-40-0A4I4M
# 61    TARGET-40-0A4I4O
# 62    TARGET-40-0A4I5B
# 63    TARGET-40-0A4I6O
# 64    TARGET-40-0A4I8U
# 65    TARGET-40-PAPFLB
# 66    TARGET-40-PAKFVX
# 67    TARGET-40-PAKXLD
# ...

# %%
manifest_df['entity_submitter_id']
# Out:
# 0      TARGET-30-PATHVK-01A-01R
# 1      TARGET-30-PASXIE-01A-01R
# 2      TARGET-30-PAPTAN-01A-01R
# 3      TARGET-30-PAPUNH-01A-01R
# 4      TARGET-20-PANLKB-09A-03R
# 5      TARGET-20-PAPVDV-03A-01R
# 6      TARGET-20-PASJTM-09A-01R
# 7      TARGET-20-PASINN-04A-02R
# 8      TARGET-50-PALKRS-01A-01R
# 9      TARGET-50-PAKZHF-01A-01R
# 10     TARGET-50-PAJMEL-01A-01R
# 11     TARGET-50-PAJNCZ-01A-01R
# 12     TARGET-50-PAKSCC-01A-01R
# 13     TARGET-50-PAKYFC-01A-01R
# 14     TARGET-50-PAJNZU-01A-01R
# 15     TARGET-50-PAJNTJ-01A-01R
# 16     TARGET-50-PAJNUP-01A-01R
# 17     TARGET-50-PAJPEW-01A-01R
# 18     TARGET-50-PAJNNR-01A-01R
# 19     TARGET-50-PAKULH-01A-02R
# 20     TARGET-50-PALLFB-01A-01R
# 21     TARGET-50-PALJIP-01A-01R
# 22     TARGET-50-PAJNBN-01A-01R
# 23     TARGET-50-PAJNSL-11A-01R
# 24     TARGET-50-PAJMSE-01A-01R
# 25     TARGET-50-PAJMVC-01A-01R
# 26     TARGET-50-PAECJB-01A-01R
# 27     TARGET-50-PALGLU-01A-01R
# 28     TARGET-50-PAKMSV-01A-01R
# ...
